# %% [markdown]
# # CIFAR Image Generator on Google Colab
#
# This notebook allows you to train and test the **CIFAR Image Generator** on Google Colab's infrastructure (GPU recommended).

# %%
# 1. Check GPU Availability
# !nvidia-smi

# %%
# 2. Clone the Repository
import os

# Ensure we are in the default workspace
# %cd /content

user = "Bhavikupadhyay"
repo = "cifar-image-generator"

if os.path.exists(repo):
    print("Repository folder exists. Removing it to ensure fresh clone...")
    # !rm -rf {repo}

# Clone the repository (Public)
# !git clone https://github.com/{user}/{repo}.git

# Enter the directory
# %cd {repo}

# %%
# 3. Install Dependencies
# We avoid installing requirements.txt deeply to prevent conflicting with Colab's pre-installed 
# torch/numpy versions (which causes 'numpy.dtype size changed' errors).
# We only install what might be missing or safe to update.

# !pip install wandb

# %%
# 4. Run Training
# Creates a new run in runs/
# You can modify hyperparameters here if needed by importing Config

from src import Config
from train import train
import torch

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

# Create a config for a short run using GPU
cfg = Config(
    run_name='colab_quick_test',
    num_epochs=5,          # Train for 5 epochs
    batch_size=128,
    save_every_epochs=1,
    sample_every_epochs=1,
    num_workers=2,
    use_wandb=False        # Set to True if you want to login to wandb
)

print("Starting training on Colab...")
train(cfg)

# %%
# 5. Run Inference
# !python inference.py --run_name colab_quick_test --num_samples 16 --device cuda

# %%
# 6. Visualize Results
from IPython.display import Image, display
import os

img_path = 'runs/colab_quick_test/inference/inference_sample.png'
if os.path.exists(img_path):
    display(Image(filename=img_path))
else:
    print("Image not found. Check if inference ran successfully.")
